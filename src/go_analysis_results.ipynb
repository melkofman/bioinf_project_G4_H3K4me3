# %%
import pandas as pd

# %%
data_path = '../data/analysis_data.txt'
delimiter = '\t'
line_terminator = '\r'

# %%
data = pd.read_csv(data_path, sep=delimiter, lineterminator=line_terminator)

data
# Out:
#                         GO biological process complete  \
# 0    \nregulation of dendrite morphogenesis (GO:004...
# 1      \nnephron epithelium morphogenesis (GO:0072088)
# 2    \nregulation of dendrite development (GO:0050773)
# 3          \nnephron tubule morphogenesis (GO:0072078)
# 4                 \nnephron morphogenesis (GO:0072028)
# ..                                                 ...
# 581  \ndetection of chemical stimulus involved in s...
# 582  \ndetection of chemical stimulus involved in s...
# 583  \ndetection of chemical stimulus involved in s...
# 584                        \nopsonization (GO:0008228)
# 585                                                 \n
#
#      Homo sapiens - REFLIST (20595)  intersect.genes_uniq.txt (8324)  \
# 0                              67.0                             54.0
# 1                              64.0                             49.0
# 2                             104.0                             79.0
# ...

# %%
data['FDR'] = pd.to_numeric(data['intersect.genes_uniq.txt (FDR)'])

(data.sort_values(by=['FDR'])).head(3)
# Out:
#                         GO biological process complete  \
# 583  \ndetection of chemical stimulus involved in s...
# 582  \ndetection of chemical stimulus involved in s...
# 579      \ndetection of chemical stimulus (GO:0009593)
#
#      Homo sapiens - REFLIST (20595)  intersect.genes_uniq.txt (8324)  \
# 583                           486.0                              0.0
# 582                           441.0                              0.0
# 579                           522.0                             12.0
#
#      intersect.genes_uniq.txt (expected)  \
# 583                               196.43
# 582                               178.24
# 579                               210.98
#
#     intersect.genes_uniq.txt (over/under)  \
# 583                                     -
# 582                                     -
# 579                                     -
#
#     intersect.genes_uniq.txt (fold Enrichment)  \
# 583                                     < 0.01
# ...
